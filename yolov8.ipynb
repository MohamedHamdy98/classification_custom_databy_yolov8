# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedHamdy98/classification_custom_databy_yolov8/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
import sys
sys.path.append("/content/drive/MyDrive/colab_env/lib/python3.10/site-packages")

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install ultralytics==8.2.48

# %%
import cv2
from ultralytics import YOLO, solutions

# %%
model = YOLO("yolov8n.pt")

# %%
model_classification = YOLO('yolov8n-cls.pt')
# Out:
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 66.0MB/s]

# %%
dataset = "/content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset"

# %%
results = model_classification.train(data=dataset, epochs=4, imgsz=224)
# Out:
# New https://pypi.org/project/ultralytics/8.2.48 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.39 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from IPython import display
display.clear_output()
from IPython.display import display, Image

# %%
Image(filename='/content/runs/classify/train/confusion_matrix.png')

# %%
model_predict_path = '/content/runs/classify/train/weights/best.pt'
model_predict_classification = YOLO(model_predict_path)

# %%
results = model_predict_classification('/content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten apples/Screen Shot 2018-06-07 at 2.18.25 PM.png')
# Out:
# image 1/1 /content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten apples/Screen Shot 2018-06-07 at 2.18.25 PM.png: 224x224 rotten apples 1.00, rotten oranges 0.00, fresh apples 0.00, fresh oranges 0.00, rotten banana 0.00, 31.9ms
# Speed: 103.4ms preprocess, 31.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
results = model_classification(source='/content/rb.jpg')
# Out:
# image 1/1 /content/rb.jpg: 224x224 rotten banana 1.00, fresh banana 0.00, rotten oranges 0.00, rotten apples 0.00, fresh apples 0.00, 22.1ms
# Speed: 9.7ms preprocess, 22.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
import glob
import os
folder_path = [
    '/content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/fresh apples/',
    '/content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/fresh banana/',
    '/content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/fresh oranges/',
    '/content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten apples/',
    '/content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten banana/',
    '/content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten oranges/'
]
for path in folder_path:
  image_files = glob.glob(os.path.join(path,'*.png'))
  print(image_files[0])
# Out:
# /content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/fresh apples/rotated_by_15_Screen Shot 2018-06-08 at 4.59.44 PM.png
# /content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/fresh banana/rotated_by_15_Screen Shot 2018-06-12 at 10.01.46 PM.png
# /content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/fresh oranges/rotated_by_15_Screen Shot 2018-06-12 at 11.52.16 PM.png
# /content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten apples/rotated_by_15_Screen Shot 2018-06-07 at 2.15.50 PM.png
# /content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten banana/rotated_by_15_Screen Shot 2018-06-12 at 8.47.41 PM.png
# /content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten oranges/rotated_by_15_Screen Shot 2018-06-12 at 11.20.13 PM.png

# %%
for i in image_files:
  model_classification(source=i, conf=0.30)
# Out:
# image 1/1 /content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten oranges/rotated_by_15_Screen Shot 2018-06-12 at 11.20.13 PM.png: 224x224 rotten oranges 1.00, fresh apples 0.00, rotten apples 0.00, fresh oranges 0.00, rotten banana 0.00, 32.0ms
# Speed: 7.4ms preprocess, 32.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/dataset_finalProject_vgg16/fruits_dataset/test/rotten oranges/rotated_by_15_Screen Shot 2018-06-12 at 11.21.29 PM.png: 224x224 rotten oranges 1.00, rotten apples 0.00, fresh oranges 0.00, rotten banana 0.00, fresh banana 0.00, 29.0ms
# Speed: 7.7ms preprocess, 29.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# ...
